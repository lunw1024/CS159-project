# %%
from glob import glob
import os
import re
import pandas as pd
pd.set_option("display.max_colwidth", None)

# %%
data_path = "/content/drive/MyDrive/CS 159/"
assert os.path.isdir(data_path)

# %%
# internal representations
internal_rep_files = glob(data_path + "internal_representations/*.csv")
internal_rep_df = pd.DataFrame(
    columns=[
        "file", "created_at", "task_type", "task_size", "task_steps",
        "num_questions", "model", "prompt_type", "accuracy"
    ]
)

for file in internal_rep_files:
  created_at = os.path.getmtime(file) * (10**9)
  task_type = re.search("(?<=type-)(.*)(?=_size)", file).group(0)
  task_size = re.search("(?<=_size-)(.*)(?=_steps)", file).group(0)
  task_steps = re.search("(?<=steps-)(.*)(?=_seed)", file).group(0)
  splits = file.split("_")
  model_name = splits[-2]
  prompt_type = splits[-1].replace(".csv", "")
  this_df = pd.read_csv(file)
  num_questions = this_df.shape[0]
  accuracy = this_df["Is Correct"].astype(int).mean()
  internal_rep_df.loc[len(internal_rep_df), :] = [
      file, created_at, task_type, task_size, task_steps, num_questions,
      model_name, prompt_type, accuracy
  ]
internal_rep_df["created_at"] = pd.to_datetime(internal_rep_df["created_at"])

internal_rep_df
# Out:
#                                                                                                                                 file  \
# 0    /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_Llama8b_internalrep-baseline.csv
# 1   /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_Llama70b_internalrep-baseline.csv
# 2                   /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_Llama70b_base.csv
# 3                   /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_Llama70b_grid.csv
# 4                    /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_Llama70b_csv.csv
# 5                  /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_Llama70b_coord.csv
# 6               /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_Llama70b_colbycol.csv
# 7                    /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_Llama8b_base.csv
# 8                    /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_Llama8b_grid.csv
# 9                     /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_Llama8b_csv.csv
# 10                  /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_Llama8b_coord.csv
# 11               /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_Llama8b_colbycol.csv
# 12                      /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_GPT4_base.csv
# 13                      /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_GPT4_grid.csv
# 14                       /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_GPT4_csv.csv
# 15                     /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_GPT4_coord.csv
# 16                  /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_GPT4_colbycol.csv
# 17                      /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_GPT3_base.csv
# 18                      /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_GPT3_grid.csv
# 19                       /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_GPT3_csv.csv
# 20                     /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_GPT3_coord.csv
# 21                  /content/drive/MyDrive/CS 159/internal_representations/type-square_size-3_steps-4_seed-3_n-100_GPT3_colbycol.csv
#
#             created_at task_type task_size task_steps num_questions     model  \
# 0  2024-05-24 01:03:38    square         3          4           100   Llama8b
# 1  2024-05-24 01:11:04    square         3          4           100  Llama70b
# 2  2024-05-24 04:14:28    square         3          4           100  Llama70b
# 3  2024-05-24 04:21:47    square         3          4           100  Llama70b
# 4  2024-05-24 04:26:28    square         3          4           100  Llama70b
# 5  2024-05-24 04:35:40    square         3          4           100  Llama70b
# 6  2024-05-24 04:40:38    square         3          4           100  Llama70b
# 7  2024-05-24 04:44:00    square         3          4           100   Llama8b
# 8  2024-05-24 04:49:55    square         3          4           100   Llama8b
# 9  2024-05-24 04:54:05    square         3          4           100   Llama8b
# 10 2024-05-24 05:01:28    square         3          4           100   Llama8b
# 11 2024-05-24 05:05:37    square         3          4           100   Llama8b
# 12 2024-05-24 06:59:32    square         3          4           100      GPT4
# 13 2024-05-24 07:33:59    square         3          4           100      GPT4
# 14 2024-05-24 07:55:00    square         3          4           100      GPT4
# 15 2024-05-24 08:31:34    square         3          4           100      GPT4
# 16 2024-05-25 06:32:09    square         3          4           100      GPT4
# 17 2024-05-25 06:34:18    square         3          4           100      GPT3
# 18 2024-05-25 06:38:27    square         3          4           100      GPT3
# 19 2024-05-25 06:40:40    square         3          4           100      GPT3
# 20 2024-05-25 06:44:12    square         3          4           100      GPT3
# 21 2024-05-25 06:47:20    square         3          4           100      GPT3
#
#              prompt_type accuracy
# 0   internalrep-baseline     0.19
# 1   internalrep-baseline     0.63
# 2                   base      0.8
# 3                   grid     0.53
# 4                    csv     0.56
# 5                  coord     0.58
# 6               colbycol     0.49
# 7                   base     0.27
# 8                   grid     0.17
# 9                    csv     0.21
# 10                 coord      0.3
# 11              colbycol     0.18
# 12                  base     0.98
# 13                  grid     0.95
# 14                   csv      0.9
# 15                 coord     0.96
# 16              colbycol      0.9
# 17                  base     0.11
# 18                  grid      0.1
# 19                   csv     0.13
# 20                 coord     0.21
# 21              colbycol     0.14

# %%
# other baselines
model_mappings = {
    "AnthropicClient": "Claude",
    "GPT3Client": "GPT3",
    "GPT4Client": "GPT4",
    "Llama70b": "Llama70b",
    "Llama8b": "Llama8b",
    "OpenAIClient": "`OpenAI`"
}
folders = list(model_mappings.keys())
other_results_df = pd.DataFrame(
    columns=[
        "file", "filetype", "task_type", "task_size", "task_steps",
        "num_questions", "created_at", "model", "use_code", "prompt_type",
        "accuracy"
    ]
)

for folder in folders:

  files = glob(data_path+folder+"/*.csv")
  for file in files:

    # task type stuff
    task_type = re.search("(?<=type-)(.*)(?=_size)", file).group(0)
    task_size = re.search("(?<=_size-)(.*)(?=_seed)", file).group(0)
    task_steps = None
    if "steps" in task_size:
      task_steps = task_size.split("-")[-1]
      task_size = task_size.split("_")[0]

    # results analysis
    this_df = pd.read_csv(file)
    num_questions = this_df.shape[0]
    accuracy = this_df["Is Correct"].astype(int).mean()

    # code, prompting flags
    uses_code = "no_code" not in file
    prompting = re.findall("(?<=code_)(.*$)", file)
    filetype = re.findall(".+?(?=_evaluation)", file.split("/")[-1])[0]
    if len(prompting) != 0:
      prompting = prompting[-1].replace(".csv", "")
    else:
      prompting = None

    # metadata
    created_at = os.path.getmtime(file) * (10**9)

    # add to master df
    other_results_df.loc[len(other_results_df), :] = [
        file, filetype, task_type, task_size, task_steps, num_questions,
        created_at, folder, uses_code, prompting, accuracy
    ]

# post-processing
other_results_df["model"] = other_results_df["model"].map(model_mappings)
other_results_df["created_at"] = pd.to_datetime(other_results_df["created_at"])

other_results_df.head(5)
# Out:
#                                                                                                                                                file  \
# 0                             /content/drive/MyDrive/CS 159/AnthropicClient/type-ring_size-12_steps-8_seed-12_n-100_evaluation_no_code_baseline.csv
# 1                               /content/drive/MyDrive/CS 159/AnthropicClient/type-ring_size-9_steps-4_seed-9_n-100_evaluation_no_code_baseline.csv
# 2                             /content/drive/MyDrive/CS 159/AnthropicClient/type-square_size-3_steps-4_seed-3_n-100_evaluation_no_code_baseline.csv
# 3                             /content/drive/MyDrive/CS 159/AnthropicClient/type-square_size-3_steps-8_seed-3_n-100_evaluation_no_code_baseline.csv
# 4  /content/drive/MyDrive/CS 159/AnthropicClient/type-square_size-3_steps-8_seed-3_n-100_special_order-random_order_evaluation_no_code_baseline.csv
#
#                                                              filetype  \
# 0                             type-ring_size-12_steps-8_seed-12_n-100
# 1                               type-ring_size-9_steps-4_seed-9_n-100
# 2                             type-square_size-3_steps-4_seed-3_n-100
# 3                             type-square_size-3_steps-8_seed-3_n-100
# 4  type-square_size-3_steps-8_seed-3_n-100_special_order-random_order
#
#   task_type task_size task_steps num_questions          created_at   model  \
# 0      ring        12          8           100 2024-05-23 16:01:30  Claude
# 1      ring         9          4           100 2024-05-23 16:04:21  Claude
# 2    square         3          4           100 2024-05-23 16:07:05  Claude
# 3    square         3          8           100 2024-05-23 16:09:51  Claude
# 4    square         3          8           100 2024-05-23 16:12:55  Claude
#
#   use_code prompt_type accuracy
# 0    False    baseline     0.08
# 1    False    baseline     0.13
# 2    False    baseline      0.5
# 3    False    baseline     0.31
# 4    False    baseline     0.09

# %%
# comparing results
compare_df = pd.DataFrame(
    other_results_df
    .groupby(["prompt_type", "model"])
    ["accuracy"]
    .mean()
)
compare_df
# Out:
#                                accuracy
# prompt_type          model
# base                 GPT4          0.98
#                      Llama70b       0.8
#                      Llama8b       0.27
# baseline             Claude    0.362143
#                      GPT3         0.095
#                      GPT4      0.357143
#                      Llama70b  0.257143
#                      Llama8b   0.146429
# chain_of_thought     `OpenAI`      0.92
# code_use             GPT4          0.87
#                      Llama70b      0.77
# colbycol             Llama70b      0.49
#                      Llama8b       0.18
# coord                GPT4          0.96
#                      Llama70b      0.58
#                      Llama8b        0.3
# csv                  GPT4           0.9
#                      Llama70b      0.56
#                      Llama8b       0.21
# grid                 GPT4          0.95
#                      Llama70b      0.53
#                      Llama8b       0.17
# indexing             Claude       0.717
#                      GPT3      0.106429
#                      GPT4         0.715
#                      Llama70b  0.435714
#                      Llama8b   0.137143
# internalrep-baseline Llama70b      0.63
#                      Llama8b       0.19
# visualize            Llama70b      0.57
#                      `OpenAI`      0.77
# zero_shot_cot        GPT3      0.096429
#                      GPT4      0.677143
#                      Llama70b  0.433571
#                      Llama8b       0.16
# zero_shot_vot        Claude    0.434444
#                      GPT3         0.095
#                      GPT4      0.623571
#                      Llama70b  0.370714
#                      Llama8b   0.132857

# %%
compare_df.groupby(["prompt_type"]).mean()
# Out:
#                       accuracy
# prompt_type
# base                  0.683333
# baseline              0.243571
# chain_of_thought          0.92
# code_use                  0.82
# colbycol                 0.335
# coord                 0.613333
# csv                   0.556667
# grid                      0.55
# indexing              0.422257
# internalrep-baseline      0.41
# visualize                 0.67
# zero_shot_cot         0.341786
# zero_shot_vot         0.331317
